# %%
import gspread

from oauth2client.service_account import ServiceAccountCredentials

import pandas as pd

# Définition des informations d'identification
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(r"/content/drive/MyDrive/apikey.json", scope)

# Autorisation et ouverture de la feuille de calcul
client = gspread.authorize(credentials)
spreadsheet = client.open('BUDGET')
worksheet = spreadsheet.worksheet('all_combine')

# Récupération des données et création de la DataFrame
data = worksheet.get_all_values()
headers = data.pop(0)  # Retirer la première ligne et l'assigner à headers
budget = pd.DataFrame(data, columns=headers)

# %%
budget
# Out:
#       DATE/MOIS                    LIBELLE MONTANT  MOYEN DE PAIEMENT
# 0    16/03/2020  CARREFOUR SURESNES VERDUN  19.53 €                CB
# 1    19/03/2020           STIS MULTIMARKET  22.53 €                CB
# 2    19/03/2020                  PHAMARCIE   4.36 €                CB
# 3    19/03/2020                   FRANPRIX   7.63 €                TR
# 4    24/03/2020  CARREFOUR SURESNES VERDUN  99.15 €                CB
# ..          ...                        ...      ...               ...
# 497                          PLATS CHINOIS   22.00€               ESP
# 498  25/08/2023                  CARREFOUR  190.00€     CB BOURSO FLO
# 499                                         123.50€     CB BOURSO FLO
# 500                                   TGTG   12.00€     CB BOURSO FLO
# 501  07/09/2023                  CARREFOUR   12.60€      CB BOURSO RX
#
# [502 rows x 4 columns]

# %%
budget = budget.replace('', None)

# %%
budget.rename(columns={"DATE/MOIS": "date", "LIBELLE": "place","MOYEN DE PAIEMENT":"paiment_method", "MONTANT ":"amount"},inplace = True)

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            340 non-null    object
#  1   place           432 non-null    object
#  2   amount          502 non-null    object
#  3   paiment_method  497 non-null    object
# dtypes: object(4)
# memory usage: 15.8+ KB

# %%
#fill null data with previous data
budget.ffill(inplace=True)

# %%
budget
# Out:
#            date                      place   amount paiment_method
# 0    16/03/2020  CARREFOUR SURESNES VERDUN  19.53 €             CB
# 1    19/03/2020           STIS MULTIMARKET  22.53 €             CB
# 2    19/03/2020                  PHAMARCIE   4.36 €             CB
# 3    19/03/2020                   FRANPRIX   7.63 €             TR
# 4    24/03/2020  CARREFOUR SURESNES VERDUN  99.15 €             CB
# ..          ...                        ...      ...            ...
# 497  19/08/2023              PLATS CHINOIS   22.00€            ESP
# 498  25/08/2023                  CARREFOUR  190.00€  CB BOURSO FLO
# 499  25/08/2023                  CARREFOUR  123.50€  CB BOURSO FLO
# 500  25/08/2023                       TGTG   12.00€  CB BOURSO FLO
# 501  07/09/2023                  CARREFOUR   12.60€   CB BOURSO RX
#
# [502 rows x 4 columns]

# %%
budget['date'] = pd.to_datetime(budget['date'],dayfirst=True)
budget['month'] = budget['date'].dt.month
budget['year'] = budget['date'].dt.year

# %%
#defining the cleaning price function
def clean_amount (amount):
  amount = float(amount.replace('€', '').replace(',', ''))
  return amount

#applying the function to the price column of df_calendar
budget['amount'] = budget['amount'].apply(lambda x: clean_amount(x))

#transforming the column as a float
budget['amount'] = budget['amount'].astype(float)

# %%
budget
# Out:
#           date                      place  amount paiment_method  month  year
# 0   2020-03-16  CARREFOUR SURESNES VERDUN   19.53             CB      3  2020
# 1   2020-03-19           STIS MULTIMARKET   22.53             CB      3  2020
# 2   2020-03-19                  PHAMARCIE    4.36             CB      3  2020
# 3   2020-03-19                   FRANPRIX    7.63             TR      3  2020
# 4   2020-03-24  CARREFOUR SURESNES VERDUN   99.15             CB      3  2020
# ..         ...                        ...     ...            ...    ...   ...
# 497 2023-08-19              PLATS CHINOIS   22.00            ESP      8  2023
# 498 2023-08-25                  CARREFOUR  190.00  CB BOURSO FLO      8  2023
# 499 2023-08-25                  CARREFOUR  123.50  CB BOURSO FLO      8  2023
# 500 2023-08-25                       TGTG   12.00  CB BOURSO FLO      8  2023
# 501 2023-09-07                  CARREFOUR   12.60   CB BOURSO RX      9  2023
#
# [502 rows x 6 columns]

# %%
budget['paiment_method'].value_counts()
# Out:
# TR                              80
# ESP                             75
# CB CJ                           59
# CB                              41
# CB RX                           33
# CB*                             28
# CB FLO                          28
# CB CJ                           21
# CB                               9
# TR RX                            8
# ESP*                             8
# ESP+TR                           7
#  CB RX BOURS (CARTE CADEAUX)     7
# CB BOURS RX                      7
# CB BOURSO RX                     6
# TR*                              6
# WECHAT PAY                       6
# CAGNOTTE                         6
# CB BOURSO FLO                    6
# CB BOURS FLO                     6
# TR+ESP                           5
# TR+CB                            4
# TR FLO                           3
# TR +ESP                          3
# CB RX HB                         3
# CB+ESP                           2
# ESP+CB                           2
# ESP + TR                         2
# ESP+CB FLO                       2
# CB*                              1
#  CB*                             1
# CB CJ + TR                       1
# GAGNOTTE                         1
# CARTE CADEUX+ CB RX              1
# CB BI                            1
# CB +TR                           1
# ESP                              1
# ESP+ TR+CB                       1
# ESP +CB                          1
# WECHAT                           1
# TR +CB                           1
# CB RX BN                         1
# CB RX                            1
# CB+TR                            1
# CBRX                             1
# CB RX B                          1
# CB B RX                          1
# TR ESP                           1
# TR + ESP                         1
# CB RX+FLO                        1
# CB F                             1
# CB BF                            1
# CB *                             1
# CB flo                           1
# TR+ ESP                          1
# ESP / CB                         1
# DIVERS                           1
# CB BOURSO RX+FORTUNEO            1
# Name: paiment_method, dtype: int64

# %%
#budget['paiment_method'] = budget['paiment_method'].replace(r'(.*CB.*RX|Ruixue|ruixue.*)', 'Carte Ruixue', regex=True).replace(r'(.*CB.*FLO.*)', 'Carte Flo', regex=True).replace(r'(.*CB.*CJ.*)', 'Carte compte-joint', regex=True).replace(r'.*CB.*', 'Carte indéterminée', regex=True).str.replace('^ESP.*','Espèce').str.replace('^TR.*','Ticket resto').str.replace('^WECHAT.*','Wechat').replace('GAGNOTTE','Cagnotte').replace('CAGNOTTE','Cagnotte')

# %%
budget['paiment_method'] = budget['paiment_method'].replace(r'.*CB.*', 'Carte', regex=True)\
    .replace('^ESP.*','Espèce', regex=True)\
    .replace('^TR.*','Ticket resto', regex=True)\
    .replace('^WECHAT.*','Wechat', regex=True)\
    .replace(['GAGNOTTE', 'CAGNOTTE'],'Cagnotte')

# %%
budget['place'].value_counts().head(20)
# Out:
# CARREFOUR SURESNES VERDUN    49
# CASINO SUPERMARCHE           24
# CARREFOUR                    24
# Casino supermarché           23
# CARREFOUR MONTESSON          19
# MARCHE                       19
# CARREFOUR DRIVE              18
# Carrefour Montesson          16
# UBEREATS HEISENBURGER        10
# MARCHE+BOUCHERIE              9
# BOULANGERIE                   9
# SUPER U                       9
# GRAND FRAIS                   8
# MONOPRIX PLUS                 8
# UBER EATS Breton burger       8
# CASINO                        8
# CARREFOUR CITY                6
# HELLO FRESH                   6
# MON MARCHE                    6
# Ubereats Breton burger        5
# Name: place, dtype: int64

# %%
import re

pattern_carref = re.compile(r'.*carref.*', re.IGNORECASE)
pattern_casino = re.compile(r'.*CASINO.*', re.IGNORECASE)
pattern_ubereats = re.compile(r'.*UBER.*', re.IGNORECASE)

budget['place'] = budget['place'].str.replace(pattern_carref, 'Carrefour')\
    .str.replace(pattern_casino, 'Casino')\
    .str.replace(pattern_ubereats, 'Ubereats')

# %%
import plotly.express as px

fig = px.bar(budget,x='paiment_method',y='amount')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a7407678-22dc-4844-b3de-59e0e2e2dfd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7407678-22dc-4844-b3de-59e0e2e2dfd4")) {                    Plotly.newPlot(                        "a7407678-22dc-4844-b3de-59e0e2e2dfd4",                        [{"alignmentgroup":"True","hovertemplate":"paiment_method=%{x}\u003cbr\u003eamount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Carte","Carte","Carte","Ticket resto","Carte","Ticket resto","Carte","Carte","Carte","Carte","Carte","Esp\u00e8ce","Carte","Esp\u00e8ce","Carte","Carte","Esp\u00e8ce","Esp\u00e8ce","Cagnotte","Carte","Carte","Carte","Esp\u00e8ce","Carte","Carte","Esp\u00e8ce","Carte","Carte","Carte","Carte","Carte","Carte","Esp\u00e8ce","Carte","Carte","Carte","Carte","Carte","Carte","Esp\u00e8ce","Carte","Esp\u00e8ce","Carte","Carte","Carte","Esp\u00e8ce","Ticket resto","Carte","Carte","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Carte","Carte","Ticket resto","Carte","Ticket resto","Carte","Esp\u00e8ce","Carte","Esp\u00e8ce","Carte","Carte","Carte","Esp\u00e8ce","Ticket resto","Carte","Esp\u00e8ce","Ticket resto","Carte","Ticket resto","Carte","Esp\u00e8ce","Ticket resto","Carte","Ticket resto","Carte","Carte","Carte","Carte","Carte","Ticket resto","Esp\u00e8ce","Ticket resto","Carte","Carte","Ticket resto","Esp\u00e8ce","Ticket resto","Esp\u00e8ce","Carte","Carte","Ticket resto","Esp\u00e8ce","Carte","Carte","Carte","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Esp\u00e8ce","Ticket resto","Ticket resto","Ticket resto","Esp\u00e8ce","Carte","Esp\u00e8ce","Ticket resto","Carte","Ticket resto","Ticket resto","Carte","Carte","Carte","Carte","Carte","Ticket resto","Carte","Carte","Carte","Carte","Carte","Ticket resto","Carte","Carte","Carte","Carte","Ticket resto","Carte","Carte","Carte","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Esp\u00e8ce","Carte","Esp\u00e8ce","Carte","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Carte","Carte","Ticket resto","Esp\u00e8ce","Ticket resto","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Esp\u00e8ce","Ticket resto","Ticket resto","Carte","Carte","Carte","Carte","Carte","Carte","Ticket resto","Carte","Carte","Ticket resto","Carte","Carte","Carte","Ticket resto","Carte","Ticket resto","Carte","Ticket resto","Ticket resto","Carte","Carte","Ticket resto","Carte","Carte","Carte","Ticket resto","Esp\u00e8ce","Carte","Ticket resto","Carte","Carte","Carte","Ticket resto","Carte","Ticket resto","DIVERS","Carte","Ticket resto","Carte","Esp\u00e8ce","Ticket resto","Carte","Ticket resto","Ticket resto","Ticket resto","Carte","Carte","Ticket resto","Ticket resto","Carte","Ticket resto","Carte","Carte","Ticket resto","Ticket resto","Carte","Ticket resto","Ticket resto","Carte","Ticket resto","Esp\u00e8ce","Esp\u00e8ce","Esp\u00e8ce","Esp\u00e8ce","Ticket resto","Carte","Carte","Carte","Esp\u00e8ce","Carte","Carte","Ticket resto","Ticket resto","Carte","Ticket resto","Carte","Ticket resto","Ticket resto","Ticket resto","Carte","Carte","Carte","Carte","Ticket resto","Carte","Carte","Carte","Carte","Ticket resto","Carte","Ticket resto","Ticket resto","Carte","Carte","Ticket resto","Carte","Ticket resto","Carte","Ticket resto","Ticket resto","Carte","Ticket resto","Carte","Ticket resto","Carte","Carte","Carte","Carte","Ticket resto","Ticket resto","Carte","Carte","Carte","Esp\u00e8ce","Carte","Carte","Carte","Carte","Carte","Carte","Ticket resto","Carte","Ticket resto","Carte","Wechat","Carte","Carte","Carte","Carte","Ca ...

# %%
budget_monthly= budget.groupby('date',as_index=False).sum()
budget_monthly
# Out:
# <ipython-input-91-1b7a7a4f130d>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#           date  amount  month  year
# 0   2020-03-16   19.53      3  2020
# 1   2020-03-19   34.52      9  6060
# 2   2020-03-24  118.15      6  4040
# 3   2020-03-28   13.80      3  2020
# 4   2020-03-31   13.80      3  2020
# ..         ...     ...    ...   ...
# 320 2023-08-08  135.00     16  4046
# 321 2023-08-12   50.00      8  2023
# 322 2023-08-19   87.00     24  6069
# 323 2023-08-25  325.50     24  6069
# 324 2023-09-07   12.60      9  2023
#
# [325 rows x 4 columns]

# %%
fig2 = px.line(budget_monthly,x='date',y='amount')
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="306a6f85-3aa3-4b2e-ba05-ffcd48a0b28b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("306a6f85-3aa3-4b2e-ba05-ffcd48a0b28b")) {                    Plotly.newPlot(                        "306a6f85-3aa3-4b2e-ba05-ffcd48a0b28b",                        [{"hovertemplate":"date=%{x}\u003cbr\u003eamount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-03-16T00:00:00","2020-03-19T00:00:00","2020-03-24T00:00:00","2020-03-28T00:00:00","2020-03-31T00:00:00","2020-04-02T00:00:00","2020-04-09T00:00:00","2020-04-15T00:00:00","2020-04-21T00:00:00","2020-04-25T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-10T00:00:00","2020-05-13T00:00:00","2020-05-19T00:00:00","2020-05-22T00:00:00","2020-05-27T00:00:00","2020-06-01T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-11T00:00:00","2020-06-14T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-20T00:00:00","2020-06-25T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-13T00:00:00","2020-07-23T00:00:00","2020-07-28T00:00:00","2020-08-01T00:00:00","2020-08-05T00:00:00","2020-08-20T00:00:00","2020-08-26T00:00:00","2020-08-30T00:00:00","2020-09-02T00:00:00","2020-09-06T00:00:00","2020-09-08T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-15T00:00:00","2020-09-22T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-10-06T00:00:00","2020-10-10T00:00:00","2020-10-14T00:00:00","2020-10-17T00:00:00","2020-10-19T00:00:00","2020-10-21T00:00:00","2020-10-26T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-07T00:00:00","2020-11-09T00:00:00","2020-11-12T00:00:00","2020-11-15T00:00:00","2020-11-18T00:00:00","2020-11-19T00:00:00","2020-11-21T00:00:00","2020-11-24T00:00:00","2020-11-25T00:00:00","2020-11-26T00:00:00","2020-12-01T00:00:00","2020-12-03T00:00:00","2020-12-06T00:00:00","2020-12-07T00:00:00","2020-12-10T00:00:00","2020-12-30T00:00:00","2021-01-06T00:00:00","2021-01-10T00:00:00","2021-01-13T00:00:00","2021-01-17T00:00:00","2021-01-20T00:00:00","2021-01-24T00:00:00","2021-01-27T00:00:00","2021-02-03T00:00:00","2021-02-09T00:00:00","2021-02-12T00:00:00","2021-02-17T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-13T00:00:00","2021-03-14T00:00:00","2021-03-19T00:00:00","2021-03-23T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-31T00:00:00","2021-04-02T00:00:00","2021-04-06T00:00:00","2021-04-10T00:00:00","2021-04-13T00:00:00","2021-04-17T00:00:00","2021-04-21T00:00:00","2021-04-23T00:00:00","2021-04-24T00:00:00","2021-04-30T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-08T00:00:00","2021-05-20T00:00:00","2021-05-23T00:00:00","2021-05-27T00:00:00","2021-05-31T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-15T00:00:00","2021-06-18T00:00:00","2021-06-19T00:00:00","2021-06-26T00:00:00","2021-07-03T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-10T00:00:00","2021-07-24T00:00:00","2021-07-27T00:00:00","2021-07-31T00:00:00","2021-08-01T00:00:00","2021-08-04T00:00:00","2021-08-07T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-09-02T00:00:0 ...

# %%
budget.to_csv('budget_clean.csv', index=False)

# %%
# Définition des informations d'identification
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(r"/content/drive/MyDrive/apikey.json", scope)

# Autorisation et ouverture de la feuille de calcul
client = gspread.authorize(credentials)
spreadsheet = client.open('BUDGET')
worksheet = spreadsheet.worksheet('common')

# Récupération des données et création de la DataFrame
data = worksheet.get_all_values()
headers = data.pop(0)  # Retirer la première ligne et l'assigner à headers
common = pd.DataFrame(data, columns=headers)

# %%
common.head(10)
# Out:
#          date               brand      amount     where paiment_method
# 0   2020-11-7  Matelas Bellecour     479.99 €  Internet     Paypal flo
# 1   2020-11-9              Auchan     40.00 €  Internet        CB RX B
# 2  2020-11-12             Notaire  1,537.66 €               Chèque flo
# 3  2020-12-13            Bouygues     58.00 €  Internet          CB cj
# 4  2020-11-14        Leroy merlin    173.70 €  Internet          CB cj
# 5                                    146.08 €   magasin          CB cj
# 6  2020-11-15        Leroy merlin     10.50 €   MAGASIN          CB cj
# 7  2020-11-17              Auchan     42.99 €  Internet        CB RX B
# 8  2020-11-20              Auchan     36.00 €  Internet        CB RX B
# 9  2020-11-21        Leroy merlin    116.05 €   MAGASIN          CB CJ

# %%
common = common.replace('', None)

# %%
# Spécifier les colonnes à remplir vers l'avant (frontfill)
columns_to_fill = ['date', 'brand', 'paiment_method']

# Effectuer le remplissage vers l'avant sur les colonnes spécifiées
common[columns_to_fill] = common[columns_to_fill].fillna(method='ffill')

#drop les colonnes sans prix car impossible
common.dropna(subset = 'amount',inplace = True)

#rempli les null dans where par Other
common['where'].fillna('Other',inplace=True)

#applying the function to the price column of df_calendar
common['amount'] = common['amount'].apply(lambda x: clean_amount(x))

#transforming the column as a float
common['amount'] = common['amount'].astype(float)

# %%
common.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 0 to 88
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            74 non-null     object
#  1   brand           74 non-null     object
#  2   amount          74 non-null     float64
#  3   where           74 non-null     object
#  4   paiment_method  74 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 3.5+ KB

# %%
common['paiment_method'].value_counts()
# Out:
# CB CJ                          24
# PAYPAL CJ                       9
# CB FLO                          7
# CB RX B                         5
# CB cj                           4
# CB RX                           3
# CB RX H                         2
# ESP                             2
# CB CJ                           2
# Chèque flo                      2
# CB RX BOURSO                    1
# CB BOURSO+CB FLO+CJ             1
# CB FLO BOURSO                   1
# CB BOURSO(CARTE CADEAUX+ESP     1
# CB BOURSO RX                    1
# CHEQUE FLO                      1
# Paypal flo                      1
# CB CJ+CB RX                     1
# CB RX BOUSO+CB FLO BOURSO       1
# CB RX BINANCE                   1
# CB BN RX                        1
# CHEQUE                          1
# CB RXH                          1
# CAGNOTTE                        1
# Name: paiment_method, dtype: int64

# %%
# Définir le dictionnaire de correspondances avec les expressions régulières
correspondances = {
    r'.*CB.*CJ.*': 'carte compte-joint',
    r'.*PAYPAL.*': 'paypal',
    r'.*CB.*FLO.*': 'carte flo',
    r'.*CB.*RX.*': 'carte ruixue',
    r'.*CAGNOTTE.*': 'cagnotte',
    r'.*ESP.*':'Espèce',
    r'.*chèque|cheque.*' : 'chèque'
}

# Fonction de remplacement basée sur les correspondances
def remplacer_valeur(valeur):
    for motif, correspondance in correspondances.items():
        if re.match(motif, valeur, flags=re.IGNORECASE):
            return correspondance
    return autre

# Appliquer la fonction de remplacement à la colonne 'paiment_method'
common['paiment_method'] = common['paiment_method'].apply(remplacer_valeur)

# %%
common['where'].value_counts()
# Out:
# Internet    36
# INTERNET    18
# MAGASIN     14
# Other        5
# magasin      1
# Name: where, dtype: int64

# %%
common['where'] = common['where'].replace('INTERNET','Internet').replace('MAGASIN','Magasin').replace('magasin','Magasin')

# %%
common
# Out:
#           date               brand   amount     where      paiment_method
# 0    2020-11-7  Matelas Bellecour    479.99  Internet              paypal
# 1    2020-11-9              Auchan    40.00  Internet        carte ruixue
# 2   2020-11-12             Notaire  1537.66     Other              chèque
# 3   2020-12-13            Bouygues    58.00  Internet  carte compte-joint
# 4   2020-11-14        Leroy merlin   173.70  Internet  carte compte-joint
# ..         ...                 ...      ...       ...                 ...
# 84    2023-4-1            LE WAGON  4305.00     Other           carte flo
# 85    2023-4-6           CARREFOUR   629.40  Internet        carte ruixue
# 86   2023-4-15           CARREFOUR   109.00  Internet            cagnotte
# 87   2023-5-13             JO 2024   568.40  Internet        carte ruixue
# 88   2023-7-17     CARTE GRAPHIQUE  1045.00  Internet           carte flo
#
# [74 rows x 5 columns]

# %%
# Définition des informations d'identification
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(r"/content/drive/MyDrive/apikey.json", scope)

# Autorisation et ouverture de la feuille de calcul
client = gspread.authorize(credentials)
spreadsheet = client.open('BUDGET')
worksheet = spreadsheet.worksheet('CHATCHAT')

# Récupération des données et création de la DataFrame
data = worksheet.get_all_values()
headers = data.pop(0)  # Retirer la première ligne et l'assigner à headers
cat = pd.DataFrame(data, columns=headers)

# %%
cat.head()
# Out:
#          date            where    amount comment     category
# 0        2021
# 1   2021-9-30          ZOOPLUS   53.01 €                 food
# 2  2021-10-10          ZOOPLUS  108.59 €                 food
# 3              ASSOCIATION EMA  200.00 €          association
# 4  2021-10-12          ZOOPLUS   62.94 €                 food

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      38 non-null     object
#  1   where     38 non-null     object
#  2   amount    38 non-null     object
#  3   comment   38 non-null     object
#  4   category  38 non-null     object
# dtypes: object(5)
# memory usage: 1.6+ KB

# %%
cat
# Out:
#           date            where    amount                       comment  \
# 0         2021
# 1    2021-9-30          ZOOPLUS   53.01 €
# 2   2021-10-10          ZOOPLUS  108.59 €
# 3               ASSOCIATION EMA  200.00 €
# 4   2021-10-12          ZOOPLUS   62.94 €
# 5                        AMAZON   18.08 €
# 6   2021-10-20      VETERINAIRE   90.00 €
# 7    2021-11-1          ZOOPLUS   14.04 €
# 8   2021-11-11          ZOOPLUS   56.44 €
# 9                     FONTAINE    90.00 €
# 10  2021-12-12      VETERINAIRE   77.00 €
# 11
# 12        2022
# 13    2022-1-4          ZOOPLUS   69.76 €
# 14   2022-1-18      VETERINAIRE   86.00 €
# 15    2022-2-3          ZOOPLUS  137.16 €
# 16   2022-2-25          ZOOPLUS   46.39 €
# 17   2022-4-12          ZOOPLUS   75.71 €
# 18   2022-6-12          ZOOPLUS   48.40 €
# 19    2022-7-7      VETERINAIRE       99€
# 20   2022-7-16          ZOOPLUS    90.09€
# 21
# 22   2022-8-26          ZOOPLUS    55.63€
# 23   2022-9-25           OCHAMA    73.96€       Distributeur croquettes
# 24  2022-11-22          ZOOPLUS    46.99€                    Croquettes
# 25  2022-11-24          ZOOPLUS    93.36€      PATES 76 boîtes +Litière
# 26
# 27        2023
# 28   2023-1-22          ZOOPLUS    52.16€               PATES 48 boîtes
# 29   2023-1-30          ZOOPLUS    49.75€           CROQUETTES DE 6.5KG
# 30   2023-2-12          ZOOPLUS    53.47€                   LITIERES *2
# 31   2023-3-26          ZOOPLUS    54.88€               PATES 48 boîtes
# 32   2023-5-17          ZOOPLUS    91.61€    PATES 48 boîtes+2 LITIERES
# 33    2023-7-3      VETERINAIRE   100.00€
# 34                      ZOOPLUS    49.74€  PATES 48 boîtes et frandises
# 35    2023-9-1          ZOOPLUS    92.34€
# 36  2023-11-13          ZOOPLUS    59.49€
# 37  2023-12-27          ZOOPLUS    99.97€          PATES*48, croquettes
#
#        category
# 0
# 1          food
# 2          food
# 3   association
# 4          food
# 5         jouet
# 6          soin
# 7          food
# 8          food
# 9         jouet
# 10         soin
# 11
# 12
# 13         food
# 14         soin
# 15         food
# 16         food
# 17         food
# 18         food
# 19         soin
# 20         food
# 21
# 22         food
# 23        jouet
# 24         food
# 25         food
# 26
# 27
# 28         food
# 29         food
# 30         food
# 31         food
# 32         food
# 33         soin
# 34         food
# 35         food
# 36         food
# 37         food

# %%
cat = cat.replace('', None)

# %%
cat['date'] = pd.to_datetime(cat['date'],dayfirst=True)

# %%
#dropping any columns without a name
cat.drop(cat.columns[cat.columns ==''],axis=1,inplace=True)

#dropping any row with a missing amount
cat.dropna(subset=['amount'],inplace=True)

#front filling date
cat['date'].ffill(inplace=True)

#applying the function to the price column of df_calendar
cat['amount'] = cat['amount'].apply(lambda x: clean_amount(x))

#transforming the column as a float
cat['amount'] = cat['amount'].astype(float)

# %%
cat
# Out:
#          date            where  amount                       comment  \
# 1  2021-09-30          ZOOPLUS   53.01                          None
# 2  2021-10-10          ZOOPLUS  108.59                          None
# 3  2021-10-10  ASSOCIATION EMA  200.00                          None
# 4  2021-10-12          ZOOPLUS   62.94                          None
# 5  2021-10-12           AMAZON   18.08                          None
# 6  2021-10-20      VETERINAIRE   90.00                          None
# 7  2021-11-01          ZOOPLUS   14.04                          None
# 8  2021-11-11          ZOOPLUS   56.44                          None
# 9  2021-11-11        FONTAINE    90.00                          None
# 10 2021-12-12      VETERINAIRE   77.00                          None
# 13 2022-01-04          ZOOPLUS   69.76                          None
# 14 2022-01-18      VETERINAIRE   86.00                          None
# 15 2022-02-03          ZOOPLUS  137.16                          None
# 16 2022-02-25          ZOOPLUS   46.39                          None
# 17 2022-04-12          ZOOPLUS   75.71                          None
# 18 2022-06-12          ZOOPLUS   48.40                          None
# 19 2022-07-07      VETERINAIRE   99.00                          None
# 20 2022-07-16          ZOOPLUS   90.09                          None
# 22 2022-08-26          ZOOPLUS   55.63                          None
# 23 2022-09-25           OCHAMA   73.96       Distributeur croquettes
# 24 2022-11-22          ZOOPLUS   46.99                    Croquettes
# 25 2022-11-24          ZOOPLUS   93.36      PATES 76 boîtes +Litière
# 28 2023-01-22          ZOOPLUS   52.16               PATES 48 boîtes
# 29 2023-01-30          ZOOPLUS   49.75           CROQUETTES DE 6.5KG
# 30 2023-02-12          ZOOPLUS   53.47                   LITIERES *2
# 31 2023-03-26          ZOOPLUS   54.88               PATES 48 boîtes
# 32 2023-05-17          ZOOPLUS   91.61    PATES 48 boîtes+2 LITIERES
# 33 2023-07-03      VETERINAIRE  100.00                          None
# 34 2023-07-03          ZOOPLUS   49.74  PATES 48 boîtes et frandises
# 35 2023-09-01          ZOOPLUS   92.34                          None
# 36 2023-11-13          ZOOPLUS   59.49                          None
# 37 2023-12-27          ZOOPLUS   99.97          PATES*48, croquettes
#
#        category
# 1          food
# 2          food
# 3   association
# 4          food
# 5         jouet
# 6          soin
# 7          food
# 8          food
# 9         jouet
# 10         soin
# 13         food
# 14         soin
# 15         food
# 16         food
# 17         food
# 18         food
# 19         soin
# 20         food
# 22         food
# 23        jouet
# 24         food
# 25         food
# 28         food
# 29         food
# 30         food
# 31         food
# 32         food
# 33         soin
# 34         food
# 35         food
# 36         food
# 37         food

# %%
import pandas as pd
import pandas_gbq

# Define your project ID and BigQuery table name
project_id = 'dev-acolyte-384710'
table_budget = 'home_expenses.budget'
table_common = 'home_expenses.common'
table_cat = 'home_expenses.cat'


# Export the DataFrame to BigQuery
pandas_gbq.to_gbq(common, table_common, project_id=project_id, if_exists='replace')
pandas_gbq.to_gbq(cat, table_cat, project_id=project_id, if_exists='replace')
pandas_gbq.to_gbq(budget, table_budget, project_id=project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1321.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 7796.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 7423.55it/s]

# %%
budget.tail(1)
# Out:
#           date      place  amount paiment_method  month  year
# 501 2023-09-07  Carrefour    12.6          Carte      9  2023
